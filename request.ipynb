# %%
import requests
requests.post("http://localhost:8000/addname/elias")
# Out:
# <Response [200]>

# %%
requests.put("http://localhost:8000/set_right_num/6")
# Out:
# <Response [200]>

# %%
requests.get("http://localhost:8000/right_num")
# Out:
# <Response [200]>
